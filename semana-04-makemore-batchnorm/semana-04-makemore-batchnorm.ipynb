# %% [markdown]
# # Semana 4: makemore parte 3: activaciones y BatchNorm
#
# **Video:** [makemore parte 3: activaciones y BatchNorm](https://www.youtube.com/watch?v=P6sfmUTpUmc), Andrej Karpathy
#
# **Qué aprendemos:** Diagnóstico de redes profundas y BatchNorm

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"torch {torch.__version__} | device: {device}")

# %% [markdown]
# ## Notas y código
