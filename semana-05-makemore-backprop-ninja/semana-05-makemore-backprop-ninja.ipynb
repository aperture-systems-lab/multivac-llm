# %% [markdown]
# # Semana 5: makemore parte 4: Backprop Ninja
#
# **Video:** [makemore parte 4: Backprop Ninja](https://www.youtube.com/watch?v=q8SA3rM6ckI), Andrej Karpathy
#
# **Qué aprendemos:** Backpropagation manual, sin `loss.backward()`

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"torch {torch.__version__} | device: {device}")

# %% [markdown]
# ## Notas y código
