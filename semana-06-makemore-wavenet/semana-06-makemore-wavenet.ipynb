# %% [markdown]
# # Semana 6: makemore parte 5: WaveNet
#
# **Video:** [makemore parte 5: WaveNet](https://www.youtube.com/watch?v=t3YJ5hKiMQ0), Andrej Karpathy
#
# **Qué aprendemos:** Redes más profundas y funcionamiento de `torch.nn`

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"torch {torch.__version__} | device: {device}")

# %% [markdown]
# ## Notas y código
