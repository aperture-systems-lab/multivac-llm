# %% [markdown]
# # Semana 8: GPT Tokenizer
#
# **Video:** [GPT Tokenizer](https://www.youtube.com/watch?v=zduSFxRajkE), Andrej Karpathy
#
# **Qué aprendemos:** Tokenización con BPE: `encode()` y `decode()`

# %% [markdown]
# ## Setup

# %%
import regex as re
import tiktoken

# %% [markdown]
# ## Notas y código
