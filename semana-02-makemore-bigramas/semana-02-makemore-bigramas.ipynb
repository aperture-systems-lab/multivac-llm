# %% [markdown]
# # Semana 2: makemore (bigramas)
#
# **Video:** [makemore (bigramas)](https://www.youtube.com/watch?v=PaCmpygFfXo), Andrej Karpathy
#
# **Qué aprendemos:** Modelos de lenguaje por caracteres y `torch.Tensor`

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"torch {torch.__version__} | device: {device}")

# %% [markdown]
# ## Notas y código
