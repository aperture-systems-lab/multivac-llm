# %% [markdown]
# # Semana 1: micrograd
#
# **Video:** [micrograd](https://www.youtube.com/watch?v=VMj-3S1tku0), Andrej Karpathy
#
# **Qué aprendemos:** Backpropagation y cómo se entrena una red neuronal

# %% [markdown]
# ## Setup

# %%
import math
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Notas y código
