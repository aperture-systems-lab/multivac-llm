# %% [markdown]
# # Semana 9: Let's reproduce GPT-2 (124M), parte 1
#
# **Video:** [Let's reproduce GPT-2 (124M), parte 1](https://www.youtube.com/watch?v=l8pRSuU81PU), Andrej Karpathy
#
# **Qué aprendemos:** Implementación de GPT-2 y carga de sus pesos originales

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"torch {torch.__version__} | device: {device}")

# %% [markdown]
# ## Notas y código
