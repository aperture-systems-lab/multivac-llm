# %% [markdown]
# # Semana 3: makemore parte 2: MLP
#
# **Video:** [makemore parte 2: MLP](https://www.youtube.com/watch?v=TCH_1BHY58I), Andrej Karpathy
#
# **Qué aprendemos:** Perceptrón multicapa, hiperparámetros y splits de datos

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"torch {torch.__version__} | device: {device}")

# %% [markdown]
# ## Notas y código
